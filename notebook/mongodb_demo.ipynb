# %% [markdown]
# # Mongo DB setup
# # Mongo DB Storing
# # logging , exception,utility
# # EDA

# %%
# !pip install "pymongo[srv]"

# %%
print("ok")
# Out:
# ok

# %%
'''
Connection String for Mongo Db

mongodb+srv://sainath:sainath@cluster0.1bixffs.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
'''

# %%
import pandas as pd
df = pd.read_csv("Visadataset.csv")

# %%
data = df.to_dict(orient='records')

# %%
df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
df.shape
# Out:
# (25480, 12)

# %%
# data

# %%
DB_NAME = "US_VISA"
COLLECTION_NAME ="visa_data"
CONNECTION_URL = "mongodb+srv://sainath:sainath@cluster0.1bixffs.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import certifi,pymongo
client = pymongo.MongoClient(CONNECTION_URL, tlsCAFile=certifi.where())
# TO CREATE THE DATABASE
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]
# TO INSERT DATA INTO THE COLLECTION
#rec = collection.insert_many(data)

# %%
records = collection.find()

# %%
for i,j in enumerate(records):
    print(i,j)

# %%
df  = pd.DataFrame(list(collection.find()))

df.head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  666fccd865574326bbcf86a5  EZYV01      Asia           High School
# 1  666fccd865574326bbcf86a6  EZYV02      Asia              Master's
# 2  666fccd865574326bbcf86a7  EZYV03      Asia            Bachelor's
# 3  666fccd865574326bbcf86a8  EZYV04      Asia            Bachelor's
# 4  666fccd865574326bbcf86a9  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# ...

# %%
if "_id" in df.columns.to_list():
    df = df.drop(columns=["_id"],axis=1)

# %%
df.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %%
# export MONGODB_URL="mongodb+srv://sainath:sainath@cluster0.1bixffs.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
